# %%
# %load_ext dotenv
# %dotenv
# Out:
# The dotenv extension is already loaded. To reload it, use:
#   %reload_ext dotenv

# %%
# %reload_ext dotenv

# %% [markdown]
# # What are we doing?
#
# ## Objectives
#
#
# * Build a data pipeline that downloads price data from the internet, stores it locally, transforms it into return data, and stores the feature set.
#     - Getting the data.
#     - Schemas and index in Dask.
#
# * Explore the parquet format.
#     - Reading and writing parquet files.
#     - Read datasets that are stored in distributed files.
#     - Discuss Dask vs. Pandas as a small example of big vs small data.
#
# * Discuss the use of environment variables for settings.
# * Discuss how to use Jupyter notebooks and source code concurrently.
# * Logging and using a standard logger.
#
# ## About the Data
#
# + We will download the prices for a list of stocks.
# + The source is Yahoo Finance, and the data, along with its description, is available via [Kaggle](https://www.kaggle.com/datasets/jacksoncrow/stock-market-dataset).
#
#
# ## Medallion Architecture
#
# + The architecture that we are thinking about is called Medallion by [DataBricks](https://www.databricks.com/glossary/medallion-architecture). It is an ELT type of thinking, although our data is well-structured.
#
# <div>
# <image src="./images/02_medallion_architecture.png" height=300>
# </div>
#
# + In our case, we would like to optimize the number of times that we download data from the internet.
# + Ultimately, we will build a pipeline manager class to control the process of obtaining and transforming our data.
#
# <div>
# <image src="./images/02_target_pipeline_manager.png" height=250>
# </div>

# %% [markdown]
# # Download Data
#
# Download the [Stock Market Dataset from Kaggle](https://www.kaggle.com/datasets/jacksoncrow/stock-market-dataset). Note that you may be required to register for a free account. Alternatively, download the file from [this location](https://drive.google.com/drive/folders/1AA4gapDLpI194TGce1bY25sd91Km-tU3?usp=drive_link).
#
# + Extract stock prices (not ETFs) into the directory: `./05_src/data/prices_csv/`.
# + To be clear, your folder structure should include the path `05_src/data/prices_csv/stocks`.

# %% [markdown]
# The command `%run update_path.py` runs a local script that adds the repository's `./05_src/` directory to the Notebook's kernel path. This way, we can use our modules within the notebook.

# %%
# %run update_path.py

# %% [markdown]
# To load the historical price data for stocks and ETFs, use the code below. Notice the following:
#
# + Libraries are ordered from high-level to low-level libraries from the package manager. Local modules are imported at the end.
# + The function `get_logger()` is called with `__name__` as recommended by [Python's documentation](https://docs.python.org/2/howto/logging.html#logging-advanced-tutorial).

# %%
from glob import glob
import os
import pandas as pd
import random

from utils.logger import get_logger
_logs = get_logger(__name__)

# %% [markdown]
# + The [`glob` module](https://docs.python.org/3/library/glob.html) is used for finding path names that match specified patterns using Unix shell-style rules.
#
# + Notice that the module `glob` contains a function called `glob`; therefore, we used `from glob import glob` above.
#
# + The path in which we are searching for our csv files is produced by joining two strings:
#
#
#
#     - The value of the environment variable 'SRC_DIR' that we obtain with `os.getenv('SRC_DIR')` (this variable points to ./05_src).
#
#     - Another string given by "data/prices_csv/stocks/*.csv".
#
#     - Both strings are combined into an OS-consistent path using `os.path.join(...)`.
#
# + After we know the location of all our files, we sample a subset of them.

# %%
stock_files = glob(os.path.join(os.getenv('SRC_DIR'), "data/price_csv/stocks/*.csv"))

_logs.info(f'Found {len(stock_files)} stock price files.')

random.seed(42)
n_sample = 60
stock_files = random.sample(stock_files, n_sample)
_logs.info(f'Sampled {n_sample} stock price files for processing. The files are: {stock_files   }')
# Out:
# 2026-01-19 15:04:42,563, 265106820.py, 3, INFO, Found 5884 stock price files.
# 2026-01-19 15:04:42,566, 265106820.py, 8, INFO, Sampled 60 stock price files for processing. The files are: ['../../05_src/data/price_csv/stocks/HCM.csv', '../../05_src/data/price_csv/stocks/ATHM.csv', '../../05_src/data/price_csv/stocks/RILYP.csv', '../../05_src/data/price_csv/stocks/ALDX.csv', '../../05_src/data/price_csv/stocks/JHG.csv', '../../05_src/data/price_csv/stocks/CHRS.csv', '../../05_src/data/price_csv/stocks/BKTI.csv', '../../05_src/data/price_csv/stocks/REFR.csv', '../../05_src/data/price_csv/stocks/KEN.csv', '../../05_src/data/price_csv/stocks/MDRRP.csv', '../../05_src/data/price_csv/stocks/GRF.csv', '../../05_src/data/price_csv/stocks/KRC.csv', '../../05_src/data/price_csv/stocks/MICT.csv', '../../05_src/data/price_csv/stocks/AMPY.csv', '../../05_src/data/price_csv/stocks/A.csv', '../../05_src/data/price_csv/stocks/WRLSU.csv', '../../05_src/data/price_csv/stocks/PNR.csv', '../../05_src/data/price_csv/stocks/TERP.csv', '../../05_src/data/price_csv/stocks/TMSR.csv', '../../05_src/data/price_csv/stocks/TDJ.csv', '../../05_src/data/price_csv/stocks/CIK.csv', '../../05_src/data/price_csv/stocks/SMBC.csv', '../../05_src/data/price_csv/stocks/CNSP.csv', '../../05_src/data/price_csv/stocks/BLK.csv', '../../05_src/data/price_csv/stocks/CLNC.csv', '../../05_src/data/price_csv/stocks/AOSL.csv', '../../05_src/data/price_csv/stocks/LYV.csv', '../../05_src/data/price_csv/stocks/IX.csv', '../../05_src/data/price_csv/stocks/AWRE.csv', '../../05_src/data/price_csv/stocks/KNX.csv', '../../05_src/data/price_csv/stocks/TRXC.csv', '../../05_src/data/price_csv/stocks/CVCY.csv', '../../05_src/data/price_csv/stocks/UVE.csv', '../../05_src/data/price_csv/stocks/HCKT.csv', '../../05_src/data/price_csv/stocks/TFSL.csv', '../../05_src/data/price_csv/stocks/ACB.csv', '../../05_src/data/price_csv/stocks/AXP.csv', '../../05_src/data/price_csv/stocks/GLG.csv', '../../05_src/data/price_csv/stocks/MFO.csv', '../../05_src/data/price_csv/stocks/PCB.csv', '../../05_src/data/price_csv/stocks/IPDN.csv', '../../05_src/data/price_csv/stocks/DTW.csv', '../../05_src/data/price_csv/stocks/IQV.csv', '../../05_src/data/price_csv/stocks/EVRI.csv', '../../05_src/data/price_csv/stocks/LIVE.csv', '../../05_src/data/price_csv/stocks/KZR.csv', '../../05_src/data/price_csv/stocks/SO.csv', '../../05_src/data/price_csv/stocks/INFY.csv', '../../05_src/data/price_csv/stocks/BSE.csv', '../../05_src/data/price_csv/stocks/PSN.csv', '../../05_src/data/price_csv/stocks/TNAV.csv', '../../05_src/data/price_csv/stocks/APTX.csv', '../../05_src/data/price_csv/stocks/LAZY.csv', '../../05_src/data/price_csv/stocks/DK.csv', '../../05_src/data/price_csv/stocks/ZEUS.csv', '../../05_src/data/price_csv/stocks/IRBT.csv', '../../05_src/data/price_csv/stocks/AMAT.csv', '../../05_src/data/price_csv/stocks/PSB.csv', '../../05_src/data/price_csv/stocks/CTSO.csv', '../../05_src/data/price_csv/stocks/UEC.csv']

# %% [markdown]
# We load the sampled files into dataframes and concatenate them:
#
# + Start with an empty list.
# + Read each file into a dataframe and [`append()` it to the list](https://docs.python.org/3/tutorial/datastructures.html#more-on-lists). Notice that `append()` is an in-place operation (it does not return a list, it modifies the list in place).
# + Finally, we concatenate all dataframes along the vertical axis (`axis=0`) using [`pd.concat()`](https://pandas.pydata.org/docs/user_guide/merging.html#concat).
# + Notice that we do not concatenate each time that we load a dataframe. According to [Panda's documentation](https://pandas.pydata.org/docs/user_guide/merging.html#concat):
#
# > "`concat()` makes a full copy of the data, and iteratively reusing `concat()` can create unnecessary copies. Collect all DataFrame or Series objects in a list before using `concat()`."

# %%
dt_list = []
for s_file in stock_files:
    _logs.info(f"Reading file: {s_file}")
    dt = pd.read_csv(s_file).assign(
        source = os.path.basename(s_file),
        ticker = os.path.basename(s_file).replace('.csv', ''),
        Date = lambda x: pd.to_datetime(x['Date'])
    )
    dt_list.append(dt)
stock_prices = pd.concat(dt_list, axis = 0, ignore_index = True)
# Out:
# 2026-01-19 15:04:46,695, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/price_csv/stocks/HCM.csv
# 2026-01-19 15:04:46,757, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/price_csv/stocks/ATHM.csv
# 2026-01-19 15:04:46,761, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/price_csv/stocks/RILYP.csv
# 2026-01-19 15:04:46,764, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/price_csv/stocks/ALDX.csv
# 2026-01-19 15:04:46,768, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/price_csv/stocks/JHG.csv
# 2026-01-19 15:04:46,770, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/price_csv/stocks/CHRS.csv
# 2026-01-19 15:04:46,773, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/price_csv/stocks/BKTI.csv
# 2026-01-19 15:04:46,785, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/price_csv/stocks/REFR.csv
# 2026-01-19 15:04:46,792, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/price_csv/stocks/KEN.csv
# 2026-01-19 15:04:46,795, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/price_csv/stocks/MDRRP.csv
# 2026-01-19 15:04:46,798, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/price_csv/stocks/GRF.csv
# 2026-01-19 15:04:46,805, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/price_csv/stocks/KRC.csv
# 2026-01-19 15:04:46,811, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/price_csv/stocks/MICT.csv
# 2026-01-19 15:04:46,817, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/price_csv/stocks/AMPY.csv
# 2026-01-19 15:04:46,820, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/price_csv/stocks/A.csv
# 2026-01-19 15:04:46,826, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/price_csv/stocks/WRLSU.csv
# 2026-01-19 15:04:46,828, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/price_csv/stocks/PNR.csv
# 2026-01-19 15:04:46,838, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/price_csv/stocks/TERP.csv
# 2026-01-19 15:04:46,841, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/price_csv/stocks/TMSR.csv
# 2026-01-19 15:04:46,844, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/price_csv/stocks/TDJ.csv
# 2026-01-19 15:04:46,848, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/price_csv/stocks/CIK.csv
# 2026-01-19 15:04:46,855, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/price_csv/stocks/SMBC.csv
# 2026-01-19 15:04:46,860, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/price_csv/stocks/CNSP.csv
# 2026-01-19 15:04:46,862, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/price_csv/stocks/BLK.csv
# 2026-01-19 15:04:46,867, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/price_csv/stocks/CLNC.csv
# 2026-01-19 15:04:46,869, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/price_csv/stocks/AOSL.csv
# 2026-01-19 15:04:46,872, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/price_csv/stocks/LYV.csv
# 2026-01-19 15:04:46,877, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/price_csv/stocks/IX.csv
# 2026-01-19 15:04:46,884, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/price_csv/stocks/AWRE.csv
# 2026-01-19 15:04:46,889, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/price_csv/stocks/KNX.csv
# 2026-01-19 15:04:46,897, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/price_csv/stocks/TRXC.csv
# 2026-01-19 15:04:46,904, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/price_csv/stocks/CVCY.csv
# 2026-01-19 15:04:46,912, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/price_csv/stocks/UVE.csv
# 2026-01-19 15:04:46,917, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/price_csv/stocks/HCKT.csv
# 2026-01-19 15:04:46,925, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/price_csv/stocks/TFSL.csv
# 2026-01-19 15:04:46,929, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/price_csv/stocks/ACB.csv
# 2026-01-19 15:04:46,936, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/price_csv/stocks/AXP.csv
# 2026-01-19 15:04:46,948, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/price_csv/stocks/GLG.csv
# 2026-01-19 15:04:46,951, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/price_csv/stocks/MFO.csv
# 2026-01-19 15:04:46,957, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/price_csv/stocks/PCB.csv
# 2026-01-19 15:04:46,964, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/price_csv/stocks/IPDN.csv
# 2026-01-19 15:04:46,968, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/price_csv/stocks/DTW.csv
# 2026-01-19 15:04:46,972, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/price_csv/stocks/IQV.csv
# 2026-01-19 15:04:46,974, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/price_csv/stocks/EVRI.csv
# 2026-01-19 15:04:46,979, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/price_csv/stocks/LIVE.csv
# 2026-01-19 15:04:46,984, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/price_csv/stocks/KZR.csv
# 2026-01-19 15:04:46,985, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/price_csv/stocks/SO.csv
# 2026-01-19 15:04:46,993, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/price_csv/stocks/INFY.csv
# 2026-01-19 15:04:46,999, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/price_csv/stocks/BSE.csv
# 2026-01-19 15:04:47,003, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/price_csv/stocks/PSN.csv
# 2026-01-19 15:04:47,006, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/price_csv/stocks/TNAV.csv
# 2026-01-19 15:04:47,009, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/price_csv/stocks/APTX.csv
# 2026-01-19 15:04:47,010, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/price_csv/stocks/LAZY.csv
# 2026-01-19 15:04:47,012, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/price_csv/stocks/DK.csv
# 2026-01-19 15:04:47,017, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/price_csv/stocks/ZEUS.csv
# 2026-01-19 15:04:47,024, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/price_csv/stocks/IRBT.csv
# 2026-01-19 15:04:47,029, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/price_csv/stocks/AMAT.csv
# 2026-01-19 15:04:47,037, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/price_csv/stocks/PSB.csv
# 2026-01-19 15:04:47,045, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/price_csv/stocks/CTSO.csv
# 2026-01-19 15:04:47,049, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/price_csv/stocks/UEC.csv

# %% [markdown]
# Verify the structure of the `stock_prices` data using the [`info()` dataframe method](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.info.html):

# %%
stock_prices.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 230273 entries, 0 to 230272
# Data columns (total 9 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   Date       230273 non-null  datetime64[ns]
#  1   Open       230260 non-null  float64
#  2   High       230260 non-null  float64
#  3   Low        230260 non-null  float64
#  4   Close      230260 non-null  float64
#  5   Adj Close  230260 non-null  float64
#  6   Volume     230260 non-null  float64
#  7   source     230273 non-null  object
#  8   ticker     230273 non-null  object
# dtypes: datetime64[ns](1), float64(6), object(2)
# memory usage: 15.8+ MB

# %% [markdown]
# We can subset our ticker data set using standard indexing techniques. Good references for this type of data manipulation are:
#
# + [Panda's Documentation](https://pandas.pydata.org/docs/user_guide/indexing.html#indexing-and-selecting-data).
# + [Panda's Cookbook](https://pandas.pydata.org/docs/user_guide/cookbook.html#cookbook-selection).

# %% [markdown]
# From the subset data frame, select one column and convert to list.

# %%
select_tickers = stock_prices['ticker'].unique().tolist()
select_tickers
# Out:
# ['HCM',
#  'ATHM',
#  'RILYP',
#  'ALDX',
#  'JHG',
#  'CHRS',
#  'BKTI',
#  'REFR',
#  'KEN',
#  'MDRRP',
#  'GRF',
#  'KRC',
#  'MICT',
#  'AMPY',
#  'A',
#  'WRLSU',
#  'PNR',
#  'TERP',
#  'TMSR',
#  'TDJ',
#  'CIK',
#  'SMBC',
#  'CNSP',
#  'BLK',
#  'CLNC',
#  'AOSL',
#  'LYV',
#  'IX',
#  'AWRE',
#  'KNX',
#  'TRXC',
#  'CVCY',
#  'UVE',
#  'HCKT',
#  'TFSL',
#  'ACB',
#  'AXP',
#  'GLG',
#  'MFO',
#  'PCB',
#  'IPDN',
#  'DTW',
#  'IQV',
#  'EVRI',
#  'LIVE',
#  'KZR',
#  'SO',
#  'INFY',
#  'BSE',
#  'PSN',
#  'TNAV',
#  'APTX',
#  'LAZY',
#  'DK',
#  'ZEUS',
#  'IRBT',
#  'AMAT',
#  'PSB',
#  'CTSO',
#  'UEC']

# %% [markdown]
# # Storing Data in CSV
#
# + We have some data. How do we store it?
# + We can compare two options, CSV and Parquet, by measuring their performance:
#
#     - Time to save: We will measure time by using the `time` library.
#     - Space required on drive: We will use the custom function below.

# %%
def get_dir_size(path='.'):
    '''Returns the total size of files contained in path.'''
    total = 0
    with os.scandir(path) as it:
        for entry in it:
            if entry.is_file():
                total += entry.stat().st_size
            elif entry.is_dir():
                total += get_dir_size(entry.path)
    return total

# %% [markdown]
# Load the specification of a temporary directory from the environment  and create a subdirectory in it called "csv":
#
# + Use `os.getenv("TEMP_DATA")` to obtain the desired location of the temporary folder from an environment variable.
# + If the subdirectory exists, delete it using `shutil.rmtree()`; the flag `ignore_errors=True` helps us in case the subdirectory does not exist (for instance, in the first run).
# + Create a directory with path given by `csv_dir` using `os.makedirs()`; the flag `exist_ok=True` indicates that if the directory already exists, then the function will do nothing.
# + Finally, create the stock price file location, `stock_csv`, which will be used to create the csv file.

# %%
import shutil

temp = os.getenv("TEMP_DATA")
csv_dir = os.path.join(temp, "csv")

shutil.rmtree(csv_dir, ignore_errors=True)
os.makedirs(csv_dir, exist_ok=True)
stock_csv = os.path.join(csv_dir, "stock_px.csv")

# %% [markdown]
# Save the concatenated dataframe to a CSV file. We measure the time elapsed by storing the start and end times, then we calculate their difference in seconds.

# %%
import time

start = time.time()
stock_prices.to_csv(stock_csv, index = False)
end = time.time()

_logs.info(f'Writing data ({stock_prices.shape}) to csv took {end - start} seconds.')
_logs.info(f'CSV file size { os.path.getsize(stock_csv)*1e-6 } MB')
# Out:
# 2026-01-19 15:44:23,417, 807204384.py, 7, INFO, Writing data ((230273, 9)) to csv took 1.1343040466308594 seconds.
# 2026-01-19 15:44:23,420, 807204384.py, 8, INFO, CSV file size 25.988193 MB

# %% [markdown]
# ## Save Data to Parquet
#
# ### Notes on Dask
#
# We could use Pandas to save the data directly into Parquet files. However, we will use a different approach by applying the [Dask framework](https://www.dask.org/). Dask provides functionality for working with datasets that do not fit in memory and parallelization to speed up computation. A few notes on Dask and Pandas:
#
# - Pandas, Parquet, and Arrow:
#
#     + We can work with large datasets and Parquet files in Pandas, but we will generally be limited by the amount of data that can fit in our computer's memory.
#     + Pandas can write Parquet files using a PyArrow backend. In fact, recent versions of Pandas support PyArrow data types, and future versions will require a PyArrow backend.
#     + The PyArrow library is an interface between Python and the Apache Arrow project. In particular, the [Parquet data format](https://parquet.apache.org/) and [Arrow](https://arrow.apache.org/docs/python/parquet.html) are Apache projects.
#
# - Dask
#
#     + Dask is much more than an interface to Arrow: Dask provides parallel and distributed computing on Pandas-like dataframes.
#     + Dask is also relatively easy to use as it mimics Pandas' API.
#     + Dask allows us to work with larger datasets than Pandas. In a sense, it is an intermediate step between Pandas and big-data frameworks like Spark (or Databricks).
#     + If you are familiar with Pandas, a good introduction is [10 Minutes to Dask](https://docs.dask.org/en/stable/10-minutes-to-dask.html).

# %%
import dask.dataframe as dd

parquet_dir = os.path.join(temp, "parquet")
shutil.rmtree(parquet_dir, ignore_errors=True)
os.makedirs(parquet_dir, exist_ok=True)

# %%
px_dd = dd.from_pandas(stock_prices, npartitions = len(select_tickers))

start = time.time()
px_dd.to_parquet(parquet_dir, engine = "pyarrow")
end = time.time()

_logs.info(f'Writing dd ({stock_prices.shape}) to parquet took {end - start} seconds.')
_logs.info(f'Parquet file size { get_dir_size(parquet_dir)*1e-6 } MB')
# Out:
# 2026-01-19 15:44:38,289, 817812245.py, 7, INFO, Writing dd ((230273, 9)) to parquet took 0.2110121250152588 seconds.
# 2026-01-19 15:44:38,290, 817812245.py, 8, INFO, Parquet file size 8.889431 MB

# %% [markdown]
# ### Pandas, Dask, and Parquet
#
# The distinction of Pandas Dataframes, Dask Dataframes, and Parquet files is important:
#
# + Pandas dataframes combine the functionality of [NumPy](https://numpy.org/) (efficient vector operations, especially vector algebra) with a concise data manipulation framework that allows us to create columns of different data types (NumPy only allows single-type matrices), database-like operations (such as filtering rows, subsetting columns, and joining different dataframes).
# + Dask dataframes extend the functionality of Pandas dataframes beyond the confines of available memory and implement parallelized operations, among other benefits.
# + Parquet files are a file format. Parquet files can be created by Pandas and Dask, but Dask offers a superior interface. Parquet files are immutable: once written, they cannot be modified.
# + Parquet and Dask are not the same: Parquet is a file format that can be accessed by many applications and programming languages (Python, R, Power BI, etc.), while Dask is a Python package for working with large datasets using distributed computation.

# %% [markdown]
# ### Dask is Powerful, but not Infallible
#
# It is tempting to think of Dask as a super-Pandas, but each package has its advantages and disadvantages.
#
# + Dask is not good at everything (see [Dask DataFrames Best Practices](https://docs.dask.org/en/stable/dataframe-best-practices.html)).
# + A useful and somewhat idiosyncratic comparison of various data manipulation frameworks is shown below (from [DataFrames at Scale Comparison: TPC-H](https://docs.coiled.io/blog/tpch.html#when-to-use-duckdb-vs-polars-vs-dask-vs-spark))
#
# Concept              | Spark | Dask | DuckDB | Polars
# ---------------------|-------|------|--------|--------
# Fast Locally         | ❌    | 🤔  | ✅     | ✅
# Fast on Cloud (1 TB) | ✅    | ✅  | ✅     | ❌
# Fast on Cloud (10 TB)| ❌    | ✅  | ✅     | ❌
# Scales Out           | ✅    | ✅  | ❌     | ❌
# SQL                  | ✅    | 🤔  | ✅     | 🤔
# More than SQL        | ✅    | ✅  | ❌     | ✅
# Sensible Defaults    | ❌    | ✅  | ✅     | ✅
#
#
# ### Dask Best Practices
#
# Parallelism brings extra complexity and overhead. Here are a few ideas to help you decide when to use Dask (from [Dask's Best Practices](https://docs.dask.org/en/stable/best-practices.html)):
#
# #### Small is Better
#
# + Start small: if possible, use Pandas. Also, try to reduce your data using aggregation, then use Pandas.
# + More generally, NumPy, Pandas, and Scikit-Learn may have faster functions for what you need. Consult the relevant documentation, experiment, and/or consult with a colleague or expert.
#
# #### Index with Care
#
# + Use the index: it is beneficial to have a well-defined index in Dask DataFrames, as it may speed up searching (filtering) the data. A one-dimensional index is allowed.
# + Minimize full-data shuffling as much as possible: indexing is an expensive operation.
#
# ### Consider the Cost of Joins
#
# + Consider cases such as small-to-large joins, where the small dataframe fits in memory, but the large one does not. The small dataframe can be Pandas, while the larger one is a Dask dataframe.
# + Some joins are more expensive than others.
#
#     * Not expensive:
#
#         - Join a Dask DataFrame with a Pandas DataFrame.
#         - Join a Dask DataFrame with another Dask DataFrame of a single partition.
#         - Join Dask DataFrames along their indexes.
#
#     * Expensive:
#
#         - Join Dask DataFrames along columns that are not their index.

# %% [markdown]
# # How Do We Store Prices?
#
# + We can store our data as a single blob.
#
#   - This can be difficult to maintain, especially because parquet files are immutable.
#   - Using a single file, we would need to recreate the complete file any time that we update it.
#
# + An alternative strategy is to organize data files by ticker and date:
#
#   - We can create one file per ticker and month (or any other suitable frequency).
#   - Under this approach, we would only need to recreate the latest month's file at any update.

# %%
# CLean up before start
PRICE_DATA = os.getenv("PRICE_DATA")
import shutil
if os.path.exists(PRICE_DATA):
    shutil.rmtree(PRICE_DATA)

# %%
stock_prices.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume', 'source',
#        'ticker'],
#       dtype='object')

# %%
for ticker in stock_prices['ticker'].unique():
    # Filter data for ticker
    # Notice that these are Pandas dataframes
    _logs.info(f'Processing ticker: {ticker}')
    ticker_dt = stock_prices[stock_prices['ticker'] == ticker]
    ticker_dt = ticker_dt.assign(Year = ticker_dt.Date.dt.year)
    for yr in ticker_dt['Year'].unique():
        _logs.info(f'Processing year {yr} for ticker {ticker}.')
        # Filter data for year and convert to Dask dataframe
        yr_dd = dd.from_pandas(ticker_dt[ticker_dt['Year'] == yr],2)
        
        # Define path and create directories if not exist
        yr_path = os.path.join(PRICE_DATA, ticker, f"{ticker}_{yr}")
        os.makedirs(os.path.dirname(yr_path), exist_ok=True)
        _logs.info(f'Writing data to path: {yr_path}')

        # Write to Parquet
        yr_dd.to_parquet(yr_path, engine = "pyarrow")
# Out:
# 2026-01-19 15:45:15,585, 2113979629.py, 4, INFO, Processing ticker: HCM
# 2026-01-19 15:45:15,610, 2113979629.py, 8, INFO, Processing year 2016 for ticker HCM.
# 2026-01-19 15:45:15,619, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/HCM/HCM_2016
# 2026-01-19 15:45:15,634, 2113979629.py, 8, INFO, Processing year 2017 for ticker HCM.
# 2026-01-19 15:45:15,637, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/HCM/HCM_2017
# 2026-01-19 15:45:15,644, 2113979629.py, 8, INFO, Processing year 2018 for ticker HCM.
# 2026-01-19 15:45:15,646, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/HCM/HCM_2018
# 2026-01-19 15:45:15,653, 2113979629.py, 8, INFO, Processing year 2019 for ticker HCM.
# 2026-01-19 15:45:15,655, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/HCM/HCM_2019
# 2026-01-19 15:45:15,661, 2113979629.py, 8, INFO, Processing year 2020 for ticker HCM.
# 2026-01-19 15:45:15,662, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/HCM/HCM_2020
# 2026-01-19 15:45:15,670, 2113979629.py, 4, INFO, Processing ticker: ATHM
# 2026-01-19 15:45:15,677, 2113979629.py, 8, INFO, Processing year 2013 for ticker ATHM.
# 2026-01-19 15:45:15,679, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ATHM/ATHM_2013
# 2026-01-19 15:45:15,688, 2113979629.py, 8, INFO, Processing year 2014 for ticker ATHM.
# 2026-01-19 15:45:15,690, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ATHM/ATHM_2014
# 2026-01-19 15:45:15,697, 2113979629.py, 8, INFO, Processing year 2015 for ticker ATHM.
# 2026-01-19 15:45:15,699, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ATHM/ATHM_2015
# 2026-01-19 15:45:15,707, 2113979629.py, 8, INFO, Processing year 2016 for ticker ATHM.
# 2026-01-19 15:45:15,709, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ATHM/ATHM_2016
# 2026-01-19 15:45:15,717, 2113979629.py, 8, INFO, Processing year 2017 for ticker ATHM.
# 2026-01-19 15:45:15,719, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ATHM/ATHM_2017
# 2026-01-19 15:45:15,725, 2113979629.py, 8, INFO, Processing year 2018 for ticker ATHM.
# 2026-01-19 15:45:15,727, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ATHM/ATHM_2018
# 2026-01-19 15:45:15,735, 2113979629.py, 8, INFO, Processing year 2019 for ticker ATHM.
# 2026-01-19 15:45:15,737, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ATHM/ATHM_2019
# 2026-01-19 15:45:15,743, 2113979629.py, 8, INFO, Processing year 2020 for ticker ATHM.
# 2026-01-19 15:45:15,745, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ATHM/ATHM_2020
# 2026-01-19 15:45:15,753, 2113979629.py, 4, INFO, Processing ticker: RILYP
# 2026-01-19 15:45:15,760, 2113979629.py, 8, INFO, Processing year 2020 for ticker RILYP.
# 2026-01-19 15:45:15,762, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/RILYP/RILYP_2020
# 2026-01-19 15:45:15,770, 2113979629.py, 4, INFO, Processing ticker: ALDX
# 2026-01-19 15:45:15,777, 2113979629.py, 8, INFO, Processing year 2014 for ticker ALDX.
# 2026-01-19 15:45:15,780, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ALDX/ALDX_2014
# 2026-01-19 15:45:15,787, 2113979629.py, 8, INFO, Processing year 2015 for ticker ALDX.
# 2026-01-19 15:45:15,789, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ALDX/ALDX_2015
# 2026-01-19 15:45:15,796, 2113979629.py, 8, INFO, Processing year 2016 for ticker ALDX.
# 2026-01-19 15:45:15,798, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ALDX/ALDX_2016
# 2026-01-19 15:45:15,805, 2113979629.py, 8, INFO, Processing year 2017 for ticker ALDX.
# 2026-01-19 15:45:15,806, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ALDX/ALDX_2017
# 2026-01-19 15:45:15,813, 2113979629.py, 8, INFO, Processing year 2018 for ticker ALDX.
# 2026-01-19 15:45:15,815, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ALDX/ALDX_2018
# 2026-01-19 15:45:15,822, 2113979629.py, 8, INFO, Processing year 2019 for ticker ALDX.
# 2026-01-19 15:45:15,823, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ALDX/ALDX_2019
# 2026-01-19 15:45:15,830, 2113979629.py, 8, INFO, Processing year 2020 for ticker ALDX.
# 2026-01-19 15:45:15,832, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ALDX/ALDX_2020
# 2026-01-19 15:45:15,839, 2113979629.py, 4, INFO, Processing ticker: JHG
# 2026-01-19 15:45:15,847, 2113979629.py, 8, INFO, Processing year 2017 for ticker JHG.
# 2026-01-19 15:45:15,849, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/JHG/JHG_2017
# 2026-01-19 15:45:15,856, 2113979629.py, 8, INFO, Processing year 2018 for ticker JHG.
# 2026-01-19 15:45:15,858, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/JHG/JHG_2018
# 2026-01-19 15:45:15,864, 2113979629.py, 8, INFO, Processing year 2019 for ticker JHG.
# 2026-01-19 15:45:15,866, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/JHG/JHG_2019
# 2026-01-19 15:45:15,874, 2113979629.py, 8, INFO, Processing year 2020 for ticker JHG.
# 2026-01-19 15:45:15,876, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/JHG/JHG_2020
# 2026-01-19 15:45:15,882, 2113979629.py, 4, INFO, Processing ticker: CHRS
# 2026-01-19 15:45:15,890, 2113979629.py, 8, INFO, Processing year 2001 for ticker CHRS.
# 2026-01-19 15:45:15,892, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CHRS/CHRS_2001
# 2026-01-19 15:45:15,898, 2113979629.py, 8, INFO, Processing year 2002 for ticker CHRS.
# 2026-01-19 15:45:15,900, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CHRS/CHRS_2002
# 2026-01-19 15:45:15,908, 2113979629.py, 8, INFO, Processing year 2003 for ticker CHRS.
# 2026-01-19 15:45:15,909, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CHRS/CHRS_2003
# 2026-01-19 15:45:15,917, 2113979629.py, 8, INFO, Processing year 2005 for ticker CHRS.
# 2026-01-19 15:45:15,918, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CHRS/CHRS_2005
# 2026-01-19 15:45:15,924, 2113979629.py, 8, INFO, Processing year 2006 for ticker CHRS.
# 2026-01-19 15:45:15,926, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CHRS/CHRS_2006
# 2026-01-19 15:45:15,932, 2113979629.py, 8, INFO, Processing year 2007 for ticker CHRS.
# 2026-01-19 15:45:15,934, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CHRS/CHRS_2007
# 2026-01-19 15:45:15,940, 2113979629.py, 8, INFO, Processing year 2008 for ticker CHRS.
# 2026-01-19 15:45:15,942, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CHRS/CHRS_2008
# 2026-01-19 15:45:15,949, 2113979629.py, 8, INFO, Processing year 2011 for ticker CHRS.
# 2026-01-19 15:45:15,950, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CHRS/CHRS_2011
# 2026-01-19 15:45:15,956, 2113979629.py, 8, INFO, Processing year 2012 for ticker CHRS.
# 2026-01-19 15:45:15,958, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CHRS/CHRS_2012
# 2026-01-19 15:45:15,965, 2113979629.py, 8, INFO, Processing year 2013 for ticker CHRS.
# 2026-01-19 15:45:15,967, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CHRS/CHRS_2013
# 2026-01-19 15:45:15,973, 2113979629.py, 8, INFO, Processing year 2014 for ticker CHRS.
# 2026-01-19 15:45:15,974, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CHRS/CHRS_2014
# 2026-01-19 15:45:15,981, 2113979629.py, 8, INFO, Processing year 2015 for ticker CHRS.
# 2026-01-19 15:45:15,983, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CHRS/CHRS_2015
# 2026-01-19 15:45:15,989, 2113979629.py, 8, INFO, Processing year 2016 for ticker CHRS.
# 2026-01-19 15:45:15,991, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CHRS/CHRS_2016
# 2026-01-19 15:45:15,998, 2113979629.py, 8, INFO, Processing year 2017 for ticker CHRS.
# 2026-01-19 15:45:16,000, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CHRS/CHRS_2017
# 2026-01-19 15:45:16,007, 2113979629.py, 8, INFO, Processing year 2018 for ticker CHRS.
# 2026-01-19 15:45:16,009, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CHRS/CHRS_2018
# 2026-01-19 15:45:16,016, 2113979629.py, 8, INFO, Processing year 2019 for ticker CHRS.
# 2026-01-19 15:45:16,018, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CHRS/CHRS_2019
# 2026-01-19 15:45:16,025, 2113979629.py, 8, INFO, Processing year 2020 for ticker CHRS.
# 2026-01-19 15:45:16,027, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CHRS/CHRS_2020
# 2026-01-19 15:45:16,034, 2113979629.py, 4, INFO, Processing ticker: BKTI
# 2026-01-19 15:45:16,043, 2113979629.py, 8, INFO, Processing year 1980 for ticker BKTI.
# 2026-01-19 15:45:16,045, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BKTI/BKTI_1980
# 2026-01-19 15:45:16,053, 2113979629.py, 8, INFO, Processing year 1981 for ticker BKTI.
# 2026-01-19 15:45:16,055, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BKTI/BKTI_1981
# 2026-01-19 15:45:16,061, 2113979629.py, 8, INFO, Processing year 1982 for ticker BKTI.
# 2026-01-19 15:45:16,063, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BKTI/BKTI_1982
# 2026-01-19 15:45:16,069, 2113979629.py, 8, INFO, Processing year 1983 for ticker BKTI.
# 2026-01-19 15:45:16,071, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BKTI/BKTI_1983
# 2026-01-19 15:45:16,077, 2113979629.py, 8, INFO, Processing year 1984 for ticker BKTI.
# 2026-01-19 15:45:16,078, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BKTI/BKTI_1984
# 2026-01-19 15:45:16,085, 2113979629.py, 8, INFO, Processing year 1985 for ticker BKTI.
# 2026-01-19 15:45:16,087, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BKTI/BKTI_1985
# 2026-01-19 15:45:16,094, 2113979629.py, 8, INFO, Processing year 1986 for ticker BKTI.
# 2026-01-19 15:45:16,096, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BKTI/BKTI_1986
# 2026-01-19 15:45:16,102, 2113979629.py, 8, INFO, Processing year 1987 for ticker BKTI.
# 2026-01-19 15:45:16,104, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BKTI/BKTI_1987
# 2026-01-19 15:45:16,110, 2113979629.py, 8, INFO, Processing year 1988 for ticker BKTI.
# 2026-01-19 15:45:16,112, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BKTI/BKTI_1988
# 2026-01-19 15:45:16,119, 2113979629.py, 8, INFO, Processing year 1989 for ticker BKTI.
# 2026-01-19 15:45:16,120, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BKTI/BKTI_1989
# 2026-01-19 15:45:16,127, 2113979629.py, 8, INFO, Processing year 1990 for ticker BKTI.
# 2026-01-19 15:45:16,129, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BKTI/BKTI_1990
# 2026-01-19 15:45:16,135, 2113979629.py, 8, INFO, Processing year 1991 for ticker BKTI.
# 2026-01-19 15:45:16,136, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BKTI/BKTI_1991
# 2026-01-19 15:45:16,142, 2113979629.py, 8, INFO, Processing year 1992 for ticker BKTI.
# 2026-01-19 15:45:16,144, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BKTI/BKTI_1992
# 2026-01-19 15:45:16,154, 2113979629.py, 8, INFO, Processing year 1993 for ticker BKTI.
# 2026-01-19 15:45:16,156, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BKTI/BKTI_1993
# 2026-01-19 15:45:16,163, 2113979629.py, 8, INFO, Processing year 1994 for ticker BKTI.
# 2026-01-19 15:45:16,165, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BKTI/BKTI_1994
# 2026-01-19 15:45:16,172, 2113979629.py, 8, INFO, Processing year 1995 for ticker BKTI.
# 2026-01-19 15:45:16,174, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BKTI/BKTI_1995
# 2026-01-19 15:45:16,181, 2113979629.py, 8, INFO, Processing year 1996 for ticker BKTI.
# 2026-01-19 15:45:16,183, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BKTI/BKTI_1996
# 2026-01-19 15:45:16,190, 2113979629.py, 8, INFO, Processing year 1997 for ticker BKTI.
# 2026-01-19 15:45:16,193, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BKTI/BKTI_1997
# 2026-01-19 15:45:16,199, 2113979629.py, 8, INFO, Processing year 1998 for ticker BKTI.
# 2026-01-19 15:45:16,201, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BKTI/BKTI_1998
# 2026-01-19 15:45:16,207, 2113979629.py, 8, INFO, Processing year 1999 for ticker BKTI.
# 2026-01-19 15:45:16,209, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BKTI/BKTI_1999
# 2026-01-19 15:45:16,216, 2113979629.py, 8, INFO, Processing year 2000 for ticker BKTI.
# 2026-01-19 15:45:16,217, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BKTI/BKTI_2000
# 2026-01-19 15:45:16,223, 2113979629.py, 8, INFO, Processing year 2001 for ticker BKTI.
# 2026-01-19 15:45:16,225, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BKTI/BKTI_2001
# 2026-01-19 15:45:16,232, 2113979629.py, 8, INFO, Processing year 2002 for ticker BKTI.
# 2026-01-19 15:45:16,233, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BKTI/BKTI_2002
# 2026-01-19 15:45:16,241, 2113979629.py, 8, INFO, Processing year 2003 for ticker BKTI.
# 2026-01-19 15:45:16,242, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BKTI/BKTI_2003
# 2026-01-19 15:45:16,249, 2113979629.py, 8, INFO, Processing year 2004 for ticker BKTI.
# 2026-01-19 15:45:16,250, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BKTI/BKTI_2004
# 2026-01-19 15:45:16,257, 2113979629.py, 8, INFO, Processing year 2005 for ticker BKTI.
# 2026-01-19 15:45:16,258, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BKTI/BKTI_2005
# 2026-01-19 15:45:16,265, 2113979629.py, 8, INFO, Processing year 2006 for ticker BKTI.
# 2026-01-19 15:45:16,266, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BKTI/BKTI_2006
# 2026-01-19 15:45:16,272, 2113979629.py, 8, INFO, Processing year 2007 for ticker BKTI.
# 2026-01-19 15:45:16,274, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BKTI/BKTI_2007
# 2026-01-19 15:45:16,280, 2113979629.py, 8, INFO, Processing year 2008 for ticker BKTI.
# 2026-01-19 15:45:16,283, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BKTI/BKTI_2008
# 2026-01-19 15:45:16,289, 2113979629.py, 8, INFO, Processing year 2009 for ticker BKTI.
# 2026-01-19 15:45:16,291, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BKTI/BKTI_2009
# 2026-01-19 15:45:16,298, 2113979629.py, 8, INFO, Processing year 2010 for ticker BKTI.
# 2026-01-19 15:45:16,300, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BKTI/BKTI_2010
# 2026-01-19 15:45:16,308, 2113979629.py, 8, INFO, Processing year 2011 for ticker BKTI.
# 2026-01-19 15:45:16,310, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BKTI/BKTI_2011
# 2026-01-19 15:45:16,317, 2113979629.py, 8, INFO, Processing year 2012 for ticker BKTI.
# 2026-01-19 15:45:16,319, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BKTI/BKTI_2012
# 2026-01-19 15:45:16,326, 2113979629.py, 8, INFO, Processing year 2013 for ticker BKTI.
# 2026-01-19 15:45:16,328, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BKTI/BKTI_2013
# 2026-01-19 15:45:16,335, 2113979629.py, 8, INFO, Processing year 2014 for ticker BKTI.
# 2026-01-19 15:45:16,337, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BKTI/BKTI_2014
# 2026-01-19 15:45:16,343, 2113979629.py, 8, INFO, Processing year 2015 for ticker BKTI.
# 2026-01-19 15:45:16,344, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BKTI/BKTI_2015
# 2026-01-19 15:45:16,351, 2113979629.py, 8, INFO, Processing year 2016 for ticker BKTI.
# 2026-01-19 15:45:16,353, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BKTI/BKTI_2016
# 2026-01-19 15:45:16,359, 2113979629.py, 8, INFO, Processing year 2017 for ticker BKTI.
# 2026-01-19 15:45:16,361, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BKTI/BKTI_2017
# 2026-01-19 15:45:16,367, 2113979629.py, 8, INFO, Processing year 2018 for ticker BKTI.
# 2026-01-19 15:45:16,369, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BKTI/BKTI_2018
# 2026-01-19 15:45:16,375, 2113979629.py, 8, INFO, Processing year 2019 for ticker BKTI.
# 2026-01-19 15:45:16,377, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BKTI/BKTI_2019
# 2026-01-19 15:45:16,383, 2113979629.py, 8, INFO, Processing year 2020 for ticker BKTI.
# 2026-01-19 15:45:16,385, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BKTI/BKTI_2020
# 2026-01-19 15:45:16,391, 2113979629.py, 4, INFO, Processing ticker: REFR
# 2026-01-19 15:45:16,400, 2113979629.py, 8, INFO, Processing year 1993 for ticker REFR.
# 2026-01-19 15:45:16,401, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REFR/REFR_1993
# 2026-01-19 15:45:16,408, 2113979629.py, 8, INFO, Processing year 1994 for ticker REFR.
# 2026-01-19 15:45:16,409, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REFR/REFR_1994
# 2026-01-19 15:45:16,417, 2113979629.py, 8, INFO, Processing year 1995 for ticker REFR.
# 2026-01-19 15:45:16,419, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REFR/REFR_1995
# 2026-01-19 15:45:16,426, 2113979629.py, 8, INFO, Processing year 1996 for ticker REFR.
# 2026-01-19 15:45:16,428, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REFR/REFR_1996
# 2026-01-19 15:45:16,436, 2113979629.py, 8, INFO, Processing year 1997 for ticker REFR.
# 2026-01-19 15:45:16,438, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REFR/REFR_1997
# 2026-01-19 15:45:16,444, 2113979629.py, 8, INFO, Processing year 1998 for ticker REFR.
# 2026-01-19 15:45:16,445, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REFR/REFR_1998
# 2026-01-19 15:45:16,453, 2113979629.py, 8, INFO, Processing year 1999 for ticker REFR.
# 2026-01-19 15:45:16,455, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REFR/REFR_1999
# 2026-01-19 15:45:16,461, 2113979629.py, 8, INFO, Processing year 2000 for ticker REFR.
# 2026-01-19 15:45:16,463, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REFR/REFR_2000
# 2026-01-19 15:45:16,470, 2113979629.py, 8, INFO, Processing year 2001 for ticker REFR.
# 2026-01-19 15:45:16,471, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REFR/REFR_2001
# 2026-01-19 15:45:16,477, 2113979629.py, 8, INFO, Processing year 2002 for ticker REFR.
# 2026-01-19 15:45:16,479, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REFR/REFR_2002
# 2026-01-19 15:45:16,486, 2113979629.py, 8, INFO, Processing year 2003 for ticker REFR.
# 2026-01-19 15:45:16,488, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REFR/REFR_2003
# 2026-01-19 15:45:16,494, 2113979629.py, 8, INFO, Processing year 2004 for ticker REFR.
# 2026-01-19 15:45:16,496, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REFR/REFR_2004
# 2026-01-19 15:45:16,505, 2113979629.py, 8, INFO, Processing year 2005 for ticker REFR.
# 2026-01-19 15:45:16,507, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REFR/REFR_2005
# 2026-01-19 15:45:16,523, 2113979629.py, 8, INFO, Processing year 2006 for ticker REFR.
# 2026-01-19 15:45:16,525, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REFR/REFR_2006
# 2026-01-19 15:45:16,533, 2113979629.py, 8, INFO, Processing year 2007 for ticker REFR.
# 2026-01-19 15:45:16,535, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REFR/REFR_2007
# 2026-01-19 15:45:16,541, 2113979629.py, 8, INFO, Processing year 2008 for ticker REFR.
# 2026-01-19 15:45:16,543, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REFR/REFR_2008
# 2026-01-19 15:45:16,559, 2113979629.py, 8, INFO, Processing year 2009 for ticker REFR.
# 2026-01-19 15:45:16,563, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REFR/REFR_2009
# 2026-01-19 15:45:16,578, 2113979629.py, 8, INFO, Processing year 2010 for ticker REFR.
# 2026-01-19 15:45:16,584, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REFR/REFR_2010
# 2026-01-19 15:45:16,600, 2113979629.py, 8, INFO, Processing year 2011 for ticker REFR.
# 2026-01-19 15:45:16,602, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REFR/REFR_2011
# 2026-01-19 15:45:16,611, 2113979629.py, 8, INFO, Processing year 2012 for ticker REFR.
# 2026-01-19 15:45:16,614, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REFR/REFR_2012
# 2026-01-19 15:45:16,621, 2113979629.py, 8, INFO, Processing year 2013 for ticker REFR.
# 2026-01-19 15:45:16,623, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REFR/REFR_2013
# 2026-01-19 15:45:16,630, 2113979629.py, 8, INFO, Processing year 2014 for ticker REFR.
# 2026-01-19 15:45:16,633, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REFR/REFR_2014
# 2026-01-19 15:45:16,639, 2113979629.py, 8, INFO, Processing year 2015 for ticker REFR.
# 2026-01-19 15:45:16,641, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REFR/REFR_2015
# 2026-01-19 15:45:16,651, 2113979629.py, 8, INFO, Processing year 2016 for ticker REFR.
# 2026-01-19 15:45:16,653, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REFR/REFR_2016
# 2026-01-19 15:45:16,659, 2113979629.py, 8, INFO, Processing year 2017 for ticker REFR.
# 2026-01-19 15:45:16,661, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REFR/REFR_2017
# 2026-01-19 15:45:16,669, 2113979629.py, 8, INFO, Processing year 2018 for ticker REFR.
# 2026-01-19 15:45:16,670, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REFR/REFR_2018
# 2026-01-19 15:45:16,677, 2113979629.py, 8, INFO, Processing year 2019 for ticker REFR.
# 2026-01-19 15:45:16,679, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REFR/REFR_2019
# 2026-01-19 15:45:16,686, 2113979629.py, 8, INFO, Processing year 2020 for ticker REFR.
# 2026-01-19 15:45:16,688, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REFR/REFR_2020
# 2026-01-19 15:45:16,694, 2113979629.py, 4, INFO, Processing ticker: KEN
# 2026-01-19 15:45:16,703, 2113979629.py, 8, INFO, Processing year 2015 for ticker KEN.
# 2026-01-19 15:45:16,704, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEN/KEN_2015
# 2026-01-19 15:45:16,711, 2113979629.py, 8, INFO, Processing year 2016 for ticker KEN.
# 2026-01-19 15:45:16,713, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEN/KEN_2016
# 2026-01-19 15:45:16,720, 2113979629.py, 8, INFO, Processing year 2017 for ticker KEN.
# 2026-01-19 15:45:16,722, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEN/KEN_2017
# 2026-01-19 15:45:16,728, 2113979629.py, 8, INFO, Processing year 2018 for ticker KEN.
# 2026-01-19 15:45:16,730, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEN/KEN_2018
# 2026-01-19 15:45:16,740, 2113979629.py, 8, INFO, Processing year 2019 for ticker KEN.
# 2026-01-19 15:45:16,742, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEN/KEN_2019
# 2026-01-19 15:45:16,751, 2113979629.py, 8, INFO, Processing year 2020 for ticker KEN.
# 2026-01-19 15:45:16,754, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEN/KEN_2020
# 2026-01-19 15:45:16,763, 2113979629.py, 4, INFO, Processing ticker: MDRRP
# 2026-01-19 15:45:16,771, 2113979629.py, 8, INFO, Processing year 2020 for ticker MDRRP.
# 2026-01-19 15:45:16,773, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/MDRRP/MDRRP_2020
# 2026-01-19 15:45:16,780, 2113979629.py, 4, INFO, Processing ticker: GRF
# 2026-01-19 15:45:16,788, 2113979629.py, 8, INFO, Processing year 2004 for ticker GRF.
# 2026-01-19 15:45:16,790, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/GRF/GRF_2004
# 2026-01-19 15:45:16,796, 2113979629.py, 8, INFO, Processing year 2005 for ticker GRF.
# 2026-01-19 15:45:16,798, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/GRF/GRF_2005
# 2026-01-19 15:45:16,805, 2113979629.py, 8, INFO, Processing year 2006 for ticker GRF.
# 2026-01-19 15:45:16,807, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/GRF/GRF_2006
# 2026-01-19 15:45:16,814, 2113979629.py, 8, INFO, Processing year 2007 for ticker GRF.
# 2026-01-19 15:45:16,816, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/GRF/GRF_2007
# 2026-01-19 15:45:16,822, 2113979629.py, 8, INFO, Processing year 2008 for ticker GRF.
# 2026-01-19 15:45:16,824, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/GRF/GRF_2008
# 2026-01-19 15:45:16,831, 2113979629.py, 8, INFO, Processing year 2009 for ticker GRF.
# 2026-01-19 15:45:16,832, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/GRF/GRF_2009
# 2026-01-19 15:45:16,839, 2113979629.py, 8, INFO, Processing year 2010 for ticker GRF.
# 2026-01-19 15:45:16,840, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/GRF/GRF_2010
# 2026-01-19 15:45:16,847, 2113979629.py, 8, INFO, Processing year 2011 for ticker GRF.
# 2026-01-19 15:45:16,849, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/GRF/GRF_2011
# 2026-01-19 15:45:16,855, 2113979629.py, 8, INFO, Processing year 2012 for ticker GRF.
# 2026-01-19 15:45:16,857, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/GRF/GRF_2012
# 2026-01-19 15:45:16,864, 2113979629.py, 8, INFO, Processing year 2013 for ticker GRF.
# 2026-01-19 15:45:16,866, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/GRF/GRF_2013
# 2026-01-19 15:45:16,873, 2113979629.py, 8, INFO, Processing year 2014 for ticker GRF.
# 2026-01-19 15:45:16,875, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/GRF/GRF_2014
# 2026-01-19 15:45:16,881, 2113979629.py, 8, INFO, Processing year 2015 for ticker GRF.
# 2026-01-19 15:45:16,883, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/GRF/GRF_2015
# 2026-01-19 15:45:16,890, 2113979629.py, 8, INFO, Processing year 2016 for ticker GRF.
# 2026-01-19 15:45:16,892, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/GRF/GRF_2016
# 2026-01-19 15:45:16,899, 2113979629.py, 8, INFO, Processing year 2017 for ticker GRF.
# 2026-01-19 15:45:16,901, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/GRF/GRF_2017
# 2026-01-19 15:45:16,908, 2113979629.py, 8, INFO, Processing year 2018 for ticker GRF.
# 2026-01-19 15:45:16,910, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/GRF/GRF_2018
# 2026-01-19 15:45:16,917, 2113979629.py, 8, INFO, Processing year 2019 for ticker GRF.
# 2026-01-19 15:45:16,919, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/GRF/GRF_2019
# 2026-01-19 15:45:16,925, 2113979629.py, 8, INFO, Processing year 2020 for ticker GRF.
# 2026-01-19 15:45:16,927, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/GRF/GRF_2020
# 2026-01-19 15:45:16,933, 2113979629.py, 4, INFO, Processing ticker: KRC
# 2026-01-19 15:45:16,941, 2113979629.py, 8, INFO, Processing year 1997 for ticker KRC.
# 2026-01-19 15:45:16,943, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KRC/KRC_1997
# 2026-01-19 15:45:16,949, 2113979629.py, 8, INFO, Processing year 1998 for ticker KRC.
# 2026-01-19 15:45:16,951, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KRC/KRC_1998
# 2026-01-19 15:45:16,958, 2113979629.py, 8, INFO, Processing year 1999 for ticker KRC.
# 2026-01-19 15:45:16,960, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KRC/KRC_1999
# 2026-01-19 15:45:16,966, 2113979629.py, 8, INFO, Processing year 2000 for ticker KRC.
# 2026-01-19 15:45:16,968, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KRC/KRC_2000
# 2026-01-19 15:45:16,975, 2113979629.py, 8, INFO, Processing year 2001 for ticker KRC.
# 2026-01-19 15:45:16,977, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KRC/KRC_2001
# 2026-01-19 15:45:16,984, 2113979629.py, 8, INFO, Processing year 2002 for ticker KRC.
# 2026-01-19 15:45:16,985, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KRC/KRC_2002
# 2026-01-19 15:45:16,992, 2113979629.py, 8, INFO, Processing year 2003 for ticker KRC.
# 2026-01-19 15:45:16,993, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KRC/KRC_2003
# 2026-01-19 15:45:17,001, 2113979629.py, 8, INFO, Processing year 2004 for ticker KRC.
# 2026-01-19 15:45:17,003, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KRC/KRC_2004
# 2026-01-19 15:45:17,011, 2113979629.py, 8, INFO, Processing year 2005 for ticker KRC.
# 2026-01-19 15:45:17,014, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KRC/KRC_2005
# 2026-01-19 15:45:17,021, 2113979629.py, 8, INFO, Processing year 2006 for ticker KRC.
# 2026-01-19 15:45:17,023, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KRC/KRC_2006
# 2026-01-19 15:45:17,031, 2113979629.py, 8, INFO, Processing year 2007 for ticker KRC.
# 2026-01-19 15:45:17,034, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KRC/KRC_2007
# 2026-01-19 15:45:17,040, 2113979629.py, 8, INFO, Processing year 2008 for ticker KRC.
# 2026-01-19 15:45:17,042, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KRC/KRC_2008
# 2026-01-19 15:45:17,050, 2113979629.py, 8, INFO, Processing year 2009 for ticker KRC.
# 2026-01-19 15:45:17,053, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KRC/KRC_2009
# 2026-01-19 15:45:17,059, 2113979629.py, 8, INFO, Processing year 2010 for ticker KRC.
# 2026-01-19 15:45:17,061, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KRC/KRC_2010
# 2026-01-19 15:45:17,069, 2113979629.py, 8, INFO, Processing year 2011 for ticker KRC.
# 2026-01-19 15:45:17,070, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KRC/KRC_2011
# 2026-01-19 15:45:17,076, 2113979629.py, 8, INFO, Processing year 2012 for ticker KRC.
# 2026-01-19 15:45:17,078, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KRC/KRC_2012
# 2026-01-19 15:45:17,085, 2113979629.py, 8, INFO, Processing year 2013 for ticker KRC.
# 2026-01-19 15:45:17,087, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KRC/KRC_2013
# 2026-01-19 15:45:17,092, 2113979629.py, 8, INFO, Processing year 2014 for ticker KRC.
# 2026-01-19 15:45:17,094, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KRC/KRC_2014
# 2026-01-19 15:45:17,101, 2113979629.py, 8, INFO, Processing year 2015 for ticker KRC.
# 2026-01-19 15:45:17,103, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KRC/KRC_2015
# 2026-01-19 15:45:17,109, 2113979629.py, 8, INFO, Processing year 2016 for ticker KRC.
# 2026-01-19 15:45:17,112, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KRC/KRC_2016
# 2026-01-19 15:45:17,118, 2113979629.py, 8, INFO, Processing year 2017 for ticker KRC.
# 2026-01-19 15:45:17,120, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KRC/KRC_2017
# 2026-01-19 15:45:17,126, 2113979629.py, 8, INFO, Processing year 2018 for ticker KRC.
# 2026-01-19 15:45:17,128, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KRC/KRC_2018
# 2026-01-19 15:45:17,134, 2113979629.py, 8, INFO, Processing year 2019 for ticker KRC.
# 2026-01-19 15:45:17,137, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KRC/KRC_2019
# 2026-01-19 15:45:17,143, 2113979629.py, 8, INFO, Processing year 2020 for ticker KRC.
# 2026-01-19 15:45:17,145, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KRC/KRC_2020
# 2026-01-19 15:45:17,152, 2113979629.py, 4, INFO, Processing ticker: MICT
# 2026-01-19 15:45:17,159, 2113979629.py, 8, INFO, Processing year 2012 for ticker MICT.
# 2026-01-19 15:45:17,162, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/MICT/MICT_2012
# 2026-01-19 15:45:17,170, 2113979629.py, 8, INFO, Processing year 2013 for ticker MICT.
# 2026-01-19 15:45:17,172, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/MICT/MICT_2013
# 2026-01-19 15:45:17,178, 2113979629.py, 8, INFO, Processing year 2014 for ticker MICT.
# 2026-01-19 15:45:17,181, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/MICT/MICT_2014
# 2026-01-19 15:45:17,188, 2113979629.py, 8, INFO, Processing year 2015 for ticker MICT.
# 2026-01-19 15:45:17,190, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/MICT/MICT_2015
# 2026-01-19 15:45:17,197, 2113979629.py, 8, INFO, Processing year 2016 for ticker MICT.
# 2026-01-19 15:45:17,199, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/MICT/MICT_2016
# 2026-01-19 15:45:17,205, 2113979629.py, 8, INFO, Processing year 2017 for ticker MICT.
# 2026-01-19 15:45:17,207, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/MICT/MICT_2017
# 2026-01-19 15:45:17,215, 2113979629.py, 8, INFO, Processing year 2018 for ticker MICT.
# 2026-01-19 15:45:17,217, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/MICT/MICT_2018
# 2026-01-19 15:45:17,223, 2113979629.py, 8, INFO, Processing year 2019 for ticker MICT.
# 2026-01-19 15:45:17,225, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/MICT/MICT_2019
# 2026-01-19 15:45:17,231, 2113979629.py, 8, INFO, Processing year 2020 for ticker MICT.
# 2026-01-19 15:45:17,233, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/MICT/MICT_2020
# 2026-01-19 15:45:17,239, 2113979629.py, 4, INFO, Processing ticker: AMPY
# 2026-01-19 15:45:17,247, 2113979629.py, 8, INFO, Processing year 2012 for ticker AMPY.
# 2026-01-19 15:45:17,249, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/AMPY/AMPY_2012
# 2026-01-19 15:45:17,258, 2113979629.py, 8, INFO, Processing year 2013 for ticker AMPY.
# 2026-01-19 15:45:17,262, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/AMPY/AMPY_2013
# 2026-01-19 15:45:17,269, 2113979629.py, 8, INFO, Processing year 2014 for ticker AMPY.
# 2026-01-19 15:45:17,271, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/AMPY/AMPY_2014
# 2026-01-19 15:45:17,277, 2113979629.py, 8, INFO, Processing year 2015 for ticker AMPY.
# 2026-01-19 15:45:17,280, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/AMPY/AMPY_2015
# 2026-01-19 15:45:17,286, 2113979629.py, 8, INFO, Processing year 2016 for ticker AMPY.
# 2026-01-19 15:45:17,288, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/AMPY/AMPY_2016
# 2026-01-19 15:45:17,295, 2113979629.py, 8, INFO, Processing year 2017 for ticker AMPY.
# 2026-01-19 15:45:17,297, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/AMPY/AMPY_2017
# 2026-01-19 15:45:17,304, 2113979629.py, 8, INFO, Processing year 2018 for ticker AMPY.
# 2026-01-19 15:45:17,305, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/AMPY/AMPY_2018
# 2026-01-19 15:45:17,312, 2113979629.py, 8, INFO, Processing year 2019 for ticker AMPY.
# 2026-01-19 15:45:17,314, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/AMPY/AMPY_2019
# 2026-01-19 15:45:17,321, 2113979629.py, 8, INFO, Processing year 2020 for ticker AMPY.
# 2026-01-19 15:45:17,323, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/AMPY/AMPY_2020
# 2026-01-19 15:45:17,331, 2113979629.py, 4, INFO, Processing ticker: A
# 2026-01-19 15:45:17,339, 2113979629.py, 8, INFO, Processing year 1999 for ticker A.
# 2026-01-19 15:45:17,341, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/A/A_1999
# 2026-01-19 15:45:17,347, 2113979629.py, 8, INFO, Processing year 2000 for ticker A.
# 2026-01-19 15:45:17,349, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/A/A_2000
# 2026-01-19 15:45:17,356, 2113979629.py, 8, INFO, Processing year 2001 for ticker A.
# 2026-01-19 15:45:17,358, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/A/A_2001
# 2026-01-19 15:45:17,364, 2113979629.py, 8, INFO, Processing year 2002 for ticker A.
# 2026-01-19 15:45:17,366, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/A/A_2002
# 2026-01-19 15:45:17,373, 2113979629.py, 8, INFO, Processing year 2003 for ticker A.
# 2026-01-19 15:45:17,375, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/A/A_2003
# 2026-01-19 15:45:17,381, 2113979629.py, 8, INFO, Processing year 2004 for ticker A.
# 2026-01-19 15:45:17,383, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/A/A_2004
# 2026-01-19 15:45:17,389, 2113979629.py, 8, INFO, Processing year 2005 for ticker A.
# 2026-01-19 15:45:17,391, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/A/A_2005
# 2026-01-19 15:45:17,398, 2113979629.py, 8, INFO, Processing year 2006 for ticker A.
# 2026-01-19 15:45:17,400, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/A/A_2006
# 2026-01-19 15:45:17,406, 2113979629.py, 8, INFO, Processing year 2007 for ticker A.
# 2026-01-19 15:45:17,408, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/A/A_2007
# 2026-01-19 15:45:17,415, 2113979629.py, 8, INFO, Processing year 2008 for ticker A.
# 2026-01-19 15:45:17,417, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/A/A_2008
# 2026-01-19 15:45:17,423, 2113979629.py, 8, INFO, Processing year 2009 for ticker A.
# 2026-01-19 15:45:17,425, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/A/A_2009
# 2026-01-19 15:45:17,432, 2113979629.py, 8, INFO, Processing year 2010 for ticker A.
# 2026-01-19 15:45:17,434, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/A/A_2010
# 2026-01-19 15:45:17,440, 2113979629.py, 8, INFO, Processing year 2011 for ticker A.
# 2026-01-19 15:45:17,442, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/A/A_2011
# 2026-01-19 15:45:17,450, 2113979629.py, 8, INFO, Processing year 2012 for ticker A.
# 2026-01-19 15:45:17,452, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/A/A_2012
# 2026-01-19 15:45:17,459, 2113979629.py, 8, INFO, Processing year 2013 for ticker A.
# 2026-01-19 15:45:17,460, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/A/A_2013
# 2026-01-19 15:45:17,471, 2113979629.py, 8, INFO, Processing year 2014 for ticker A.
# 2026-01-19 15:45:17,473, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/A/A_2014
# 2026-01-19 15:45:17,480, 2113979629.py, 8, INFO, Processing year 2015 for ticker A.
# 2026-01-19 15:45:17,483, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/A/A_2015
# 2026-01-19 15:45:17,489, 2113979629.py, 8, INFO, Processing year 2016 for ticker A.
# 2026-01-19 15:45:17,491, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/A/A_2016
# 2026-01-19 15:45:17,499, 2113979629.py, 8, INFO, Processing year 2017 for ticker A.
# 2026-01-19 15:45:17,501, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/A/A_2017
# 2026-01-19 15:45:17,507, 2113979629.py, 8, INFO, Processing year 2018 for ticker A.
# 2026-01-19 15:45:17,509, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/A/A_2018
# 2026-01-19 15:45:17,517, 2113979629.py, 8, INFO, Processing year 2019 for ticker A.
# 2026-01-19 15:45:17,520, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/A/A_2019
# 2026-01-19 15:45:17,528, 2113979629.py, 8, INFO, Processing year 2020 for ticker A.
# 2026-01-19 15:45:17,531, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/A/A_2020
# 2026-01-19 15:45:17,540, 2113979629.py, 4, INFO, Processing ticker: WRLSU
# 2026-01-19 15:45:17,548, 2113979629.py, 8, INFO, Processing year 2017 for ticker WRLSU.
# 2026-01-19 15:45:17,550, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/WRLSU/WRLSU_2017
# 2026-01-19 15:45:17,557, 2113979629.py, 8, INFO, Processing year 2018 for ticker WRLSU.
# 2026-01-19 15:45:17,559, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/WRLSU/WRLSU_2018
# 2026-01-19 15:45:17,567, 2113979629.py, 8, INFO, Processing year 2019 for ticker WRLSU.
# 2026-01-19 15:45:17,569, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/WRLSU/WRLSU_2019
# 2026-01-19 15:45:17,577, 2113979629.py, 8, INFO, Processing year 2020 for ticker WRLSU.
# 2026-01-19 15:45:17,579, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/WRLSU/WRLSU_2020
# 2026-01-19 15:45:17,587, 2113979629.py, 4, INFO, Processing ticker: PNR
# 2026-01-19 15:45:17,595, 2113979629.py, 8, INFO, Processing year 1973 for ticker PNR.
# 2026-01-19 15:45:17,598, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PNR/PNR_1973
# 2026-01-19 15:45:17,606, 2113979629.py, 8, INFO, Processing year 1974 for ticker PNR.
# 2026-01-19 15:45:17,608, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PNR/PNR_1974
# 2026-01-19 15:45:17,617, 2113979629.py, 8, INFO, Processing year 1975 for ticker PNR.
# 2026-01-19 15:45:17,620, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PNR/PNR_1975
# 2026-01-19 15:45:17,627, 2113979629.py, 8, INFO, Processing year 1976 for ticker PNR.
# 2026-01-19 15:45:17,629, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PNR/PNR_1976
# 2026-01-19 15:45:17,636, 2113979629.py, 8, INFO, Processing year 1977 for ticker PNR.
# 2026-01-19 15:45:17,638, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PNR/PNR_1977
# 2026-01-19 15:45:17,644, 2113979629.py, 8, INFO, Processing year 1978 for ticker PNR.
# 2026-01-19 15:45:17,646, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PNR/PNR_1978
# 2026-01-19 15:45:17,653, 2113979629.py, 8, INFO, Processing year 1979 for ticker PNR.
# 2026-01-19 15:45:17,655, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PNR/PNR_1979
# 2026-01-19 15:45:17,662, 2113979629.py, 8, INFO, Processing year 1980 for ticker PNR.
# 2026-01-19 15:45:17,664, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PNR/PNR_1980
# 2026-01-19 15:45:17,671, 2113979629.py, 8, INFO, Processing year 1981 for ticker PNR.
# 2026-01-19 15:45:17,673, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PNR/PNR_1981
# 2026-01-19 15:45:17,679, 2113979629.py, 8, INFO, Processing year 1982 for ticker PNR.
# 2026-01-19 15:45:17,681, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PNR/PNR_1982
# 2026-01-19 15:45:17,688, 2113979629.py, 8, INFO, Processing year 1983 for ticker PNR.
# 2026-01-19 15:45:17,689, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PNR/PNR_1983
# 2026-01-19 15:45:17,697, 2113979629.py, 8, INFO, Processing year 1984 for ticker PNR.
# 2026-01-19 15:45:17,699, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PNR/PNR_1984
# 2026-01-19 15:45:17,705, 2113979629.py, 8, INFO, Processing year 1985 for ticker PNR.
# 2026-01-19 15:45:17,707, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PNR/PNR_1985
# 2026-01-19 15:45:17,714, 2113979629.py, 8, INFO, Processing year 1986 for ticker PNR.
# 2026-01-19 15:45:17,716, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PNR/PNR_1986
# 2026-01-19 15:45:17,723, 2113979629.py, 8, INFO, Processing year 1987 for ticker PNR.
# 2026-01-19 15:45:17,725, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PNR/PNR_1987
# 2026-01-19 15:45:17,732, 2113979629.py, 8, INFO, Processing year 1988 for ticker PNR.
# 2026-01-19 15:45:17,734, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PNR/PNR_1988
# 2026-01-19 15:45:17,741, 2113979629.py, 8, INFO, Processing year 1989 for ticker PNR.
# 2026-01-19 15:45:17,742, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PNR/PNR_1989
# 2026-01-19 15:45:17,750, 2113979629.py, 8, INFO, Processing year 1990 for ticker PNR.
# 2026-01-19 15:45:17,752, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PNR/PNR_1990
# 2026-01-19 15:45:17,759, 2113979629.py, 8, INFO, Processing year 1991 for ticker PNR.
# 2026-01-19 15:45:17,761, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PNR/PNR_1991
# 2026-01-19 15:45:17,782, 2113979629.py, 8, INFO, Processing year 1992 for ticker PNR.
# 2026-01-19 15:45:17,786, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PNR/PNR_1992
# 2026-01-19 15:45:17,801, 2113979629.py, 8, INFO, Processing year 1993 for ticker PNR.
# 2026-01-19 15:45:17,803, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PNR/PNR_1993
# 2026-01-19 15:45:17,810, 2113979629.py, 8, INFO, Processing year 1994 for ticker PNR.
# 2026-01-19 15:45:17,812, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PNR/PNR_1994
# 2026-01-19 15:45:17,821, 2113979629.py, 8, INFO, Processing year 1995 for ticker PNR.
# 2026-01-19 15:45:17,823, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PNR/PNR_1995
# 2026-01-19 15:45:17,830, 2113979629.py, 8, INFO, Processing year 1996 for ticker PNR.
# 2026-01-19 15:45:17,832, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PNR/PNR_1996
# 2026-01-19 15:45:17,838, 2113979629.py, 8, INFO, Processing year 1997 for ticker PNR.
# 2026-01-19 15:45:17,840, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PNR/PNR_1997
# 2026-01-19 15:45:17,847, 2113979629.py, 8, INFO, Processing year 1998 for ticker PNR.
# 2026-01-19 15:45:17,849, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PNR/PNR_1998
# 2026-01-19 15:45:17,855, 2113979629.py, 8, INFO, Processing year 1999 for ticker PNR.
# 2026-01-19 15:45:17,857, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PNR/PNR_1999
# 2026-01-19 15:45:17,862, 2113979629.py, 8, INFO, Processing year 2000 for ticker PNR.
# 2026-01-19 15:45:17,864, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PNR/PNR_2000
# 2026-01-19 15:45:17,872, 2113979629.py, 8, INFO, Processing year 2001 for ticker PNR.
# 2026-01-19 15:45:17,874, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PNR/PNR_2001
# 2026-01-19 15:45:17,880, 2113979629.py, 8, INFO, Processing year 2002 for ticker PNR.
# 2026-01-19 15:45:17,882, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PNR/PNR_2002
# 2026-01-19 15:45:17,889, 2113979629.py, 8, INFO, Processing year 2003 for ticker PNR.
# 2026-01-19 15:45:17,891, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PNR/PNR_2003
# 2026-01-19 15:45:17,898, 2113979629.py, 8, INFO, Processing year 2004 for ticker PNR.
# 2026-01-19 15:45:17,900, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PNR/PNR_2004
# 2026-01-19 15:45:17,907, 2113979629.py, 8, INFO, Processing year 2005 for ticker PNR.
# 2026-01-19 15:45:17,909, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PNR/PNR_2005
# 2026-01-19 15:45:17,918, 2113979629.py, 8, INFO, Processing year 2006 for ticker PNR.
# 2026-01-19 15:45:17,920, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PNR/PNR_2006
# ...
# 2026-01-19 15:45:28,269, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/AMAT/AMAT_2000
# 2026-01-19 15:45:28,277, 2113979629.py, 8, INFO, Processing year 2001 for ticker AMAT.
# 2026-01-19 15:45:28,280, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/AMAT/AMAT_2001
# 2026-01-19 15:45:28,288, 2113979629.py, 8, INFO, Processing year 2002 for ticker AMAT.
# 2026-01-19 15:45:28,290, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/AMAT/AMAT_2002
# 2026-01-19 15:45:28,297, 2113979629.py, 8, INFO, Processing year 2003 for ticker AMAT.
# 2026-01-19 15:45:28,299, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/AMAT/AMAT_2003
# 2026-01-19 15:45:28,311, 2113979629.py, 8, INFO, Processing year 2004 for ticker AMAT.
# 2026-01-19 15:45:28,314, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/AMAT/AMAT_2004
# 2026-01-19 15:45:28,321, 2113979629.py, 8, INFO, Processing year 2005 for ticker AMAT.
# 2026-01-19 15:45:28,323, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/AMAT/AMAT_2005
# 2026-01-19 15:45:28,331, 2113979629.py, 8, INFO, Processing year 2006 for ticker AMAT.
# 2026-01-19 15:45:28,333, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/AMAT/AMAT_2006
# 2026-01-19 15:45:28,339, 2113979629.py, 8, INFO, Processing year 2007 for ticker AMAT.
# 2026-01-19 15:45:28,341, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/AMAT/AMAT_2007
# 2026-01-19 15:45:28,348, 2113979629.py, 8, INFO, Processing year 2008 for ticker AMAT.
# 2026-01-19 15:45:28,351, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/AMAT/AMAT_2008
# 2026-01-19 15:45:28,358, 2113979629.py, 8, INFO, Processing year 2009 for ticker AMAT.
# 2026-01-19 15:45:28,360, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/AMAT/AMAT_2009
# 2026-01-19 15:45:28,371, 2113979629.py, 8, INFO, Processing year 2010 for ticker AMAT.
# 2026-01-19 15:45:28,374, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/AMAT/AMAT_2010
# 2026-01-19 15:45:28,385, 2113979629.py, 8, INFO, Processing year 2011 for ticker AMAT.
# 2026-01-19 15:45:28,389, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/AMAT/AMAT_2011
# 2026-01-19 15:45:28,399, 2113979629.py, 8, INFO, Processing year 2012 for ticker AMAT.
# 2026-01-19 15:45:28,401, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/AMAT/AMAT_2012
# 2026-01-19 15:45:28,408, 2113979629.py, 8, INFO, Processing year 2013 for ticker AMAT.
# 2026-01-19 15:45:28,410, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/AMAT/AMAT_2013
# 2026-01-19 15:45:28,416, 2113979629.py, 8, INFO, Processing year 2014 for ticker AMAT.
# 2026-01-19 15:45:28,418, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/AMAT/AMAT_2014
# 2026-01-19 15:45:28,424, 2113979629.py, 8, INFO, Processing year 2015 for ticker AMAT.
# 2026-01-19 15:45:28,426, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/AMAT/AMAT_2015
# 2026-01-19 15:45:28,435, 2113979629.py, 8, INFO, Processing year 2016 for ticker AMAT.
# 2026-01-19 15:45:28,437, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/AMAT/AMAT_2016
# 2026-01-19 15:45:28,444, 2113979629.py, 8, INFO, Processing year 2017 for ticker AMAT.
# 2026-01-19 15:45:28,446, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/AMAT/AMAT_2017
# 2026-01-19 15:45:28,453, 2113979629.py, 8, INFO, Processing year 2018 for ticker AMAT.
# 2026-01-19 15:45:28,457, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/AMAT/AMAT_2018
# 2026-01-19 15:45:28,464, 2113979629.py, 8, INFO, Processing year 2019 for ticker AMAT.
# 2026-01-19 15:45:28,466, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/AMAT/AMAT_2019
# 2026-01-19 15:45:28,473, 2113979629.py, 8, INFO, Processing year 2020 for ticker AMAT.
# 2026-01-19 15:45:28,475, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/AMAT/AMAT_2020
# 2026-01-19 15:45:28,481, 2113979629.py, 4, INFO, Processing ticker: PSB
# 2026-01-19 15:45:28,490, 2113979629.py, 8, INFO, Processing year 1991 for ticker PSB.
# 2026-01-19 15:45:28,492, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PSB/PSB_1991
# 2026-01-19 15:45:28,501, 2113979629.py, 8, INFO, Processing year 1992 for ticker PSB.
# 2026-01-19 15:45:28,503, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PSB/PSB_1992
# 2026-01-19 15:45:28,509, 2113979629.py, 8, INFO, Processing year 1993 for ticker PSB.
# 2026-01-19 15:45:28,511, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PSB/PSB_1993
# 2026-01-19 15:45:28,518, 2113979629.py, 8, INFO, Processing year 1994 for ticker PSB.
# 2026-01-19 15:45:28,520, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PSB/PSB_1994
# 2026-01-19 15:45:28,527, 2113979629.py, 8, INFO, Processing year 1995 for ticker PSB.
# 2026-01-19 15:45:28,529, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PSB/PSB_1995
# 2026-01-19 15:45:28,536, 2113979629.py, 8, INFO, Processing year 1996 for ticker PSB.
# 2026-01-19 15:45:28,538, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PSB/PSB_1996
# 2026-01-19 15:45:28,544, 2113979629.py, 8, INFO, Processing year 1997 for ticker PSB.
# 2026-01-19 15:45:28,546, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PSB/PSB_1997
# 2026-01-19 15:45:28,553, 2113979629.py, 8, INFO, Processing year 1998 for ticker PSB.
# 2026-01-19 15:45:28,554, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PSB/PSB_1998
# 2026-01-19 15:45:28,561, 2113979629.py, 8, INFO, Processing year 1999 for ticker PSB.
# 2026-01-19 15:45:28,563, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PSB/PSB_1999
# 2026-01-19 15:45:28,570, 2113979629.py, 8, INFO, Processing year 2000 for ticker PSB.
# 2026-01-19 15:45:28,572, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PSB/PSB_2000
# 2026-01-19 15:45:28,578, 2113979629.py, 8, INFO, Processing year 2001 for ticker PSB.
# 2026-01-19 15:45:28,580, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PSB/PSB_2001
# 2026-01-19 15:45:28,587, 2113979629.py, 8, INFO, Processing year 2002 for ticker PSB.
# 2026-01-19 15:45:28,589, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PSB/PSB_2002
# 2026-01-19 15:45:28,595, 2113979629.py, 8, INFO, Processing year 2003 for ticker PSB.
# 2026-01-19 15:45:28,597, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PSB/PSB_2003
# 2026-01-19 15:45:28,605, 2113979629.py, 8, INFO, Processing year 2004 for ticker PSB.
# 2026-01-19 15:45:28,607, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PSB/PSB_2004
# 2026-01-19 15:45:28,614, 2113979629.py, 8, INFO, Processing year 2005 for ticker PSB.
# 2026-01-19 15:45:28,616, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PSB/PSB_2005
# 2026-01-19 15:45:28,622, 2113979629.py, 8, INFO, Processing year 2006 for ticker PSB.
# 2026-01-19 15:45:28,624, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PSB/PSB_2006
# 2026-01-19 15:45:28,631, 2113979629.py, 8, INFO, Processing year 2007 for ticker PSB.
# 2026-01-19 15:45:28,633, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PSB/PSB_2007
# 2026-01-19 15:45:28,640, 2113979629.py, 8, INFO, Processing year 2008 for ticker PSB.
# 2026-01-19 15:45:28,642, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PSB/PSB_2008
# 2026-01-19 15:45:28,650, 2113979629.py, 8, INFO, Processing year 2009 for ticker PSB.
# 2026-01-19 15:45:28,652, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PSB/PSB_2009
# 2026-01-19 15:45:28,658, 2113979629.py, 8, INFO, Processing year 2010 for ticker PSB.
# 2026-01-19 15:45:28,660, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PSB/PSB_2010
# 2026-01-19 15:45:28,666, 2113979629.py, 8, INFO, Processing year 2011 for ticker PSB.
# 2026-01-19 15:45:28,668, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PSB/PSB_2011
# 2026-01-19 15:45:28,674, 2113979629.py, 8, INFO, Processing year 2012 for ticker PSB.
# 2026-01-19 15:45:28,675, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PSB/PSB_2012
# 2026-01-19 15:45:28,682, 2113979629.py, 8, INFO, Processing year 2013 for ticker PSB.
# 2026-01-19 15:45:28,684, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PSB/PSB_2013
# 2026-01-19 15:45:28,691, 2113979629.py, 8, INFO, Processing year 2014 for ticker PSB.
# 2026-01-19 15:45:28,693, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PSB/PSB_2014
# 2026-01-19 15:45:28,699, 2113979629.py, 8, INFO, Processing year 2015 for ticker PSB.
# 2026-01-19 15:45:28,701, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PSB/PSB_2015
# 2026-01-19 15:45:28,709, 2113979629.py, 8, INFO, Processing year 2016 for ticker PSB.
# 2026-01-19 15:45:28,711, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PSB/PSB_2016
# 2026-01-19 15:45:28,717, 2113979629.py, 8, INFO, Processing year 2017 for ticker PSB.
# 2026-01-19 15:45:28,719, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PSB/PSB_2017
# 2026-01-19 15:45:28,725, 2113979629.py, 8, INFO, Processing year 2018 for ticker PSB.
# 2026-01-19 15:45:28,727, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PSB/PSB_2018
# 2026-01-19 15:45:28,733, 2113979629.py, 8, INFO, Processing year 2019 for ticker PSB.
# 2026-01-19 15:45:28,735, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PSB/PSB_2019
# 2026-01-19 15:45:28,743, 2113979629.py, 8, INFO, Processing year 2020 for ticker PSB.
# 2026-01-19 15:45:28,747, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/PSB/PSB_2020
# 2026-01-19 15:45:28,756, 2113979629.py, 4, INFO, Processing ticker: CTSO
# 2026-01-19 15:45:28,764, 2113979629.py, 8, INFO, Processing year 2006 for ticker CTSO.
# 2026-01-19 15:45:28,766, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CTSO/CTSO_2006
# 2026-01-19 15:45:28,775, 2113979629.py, 8, INFO, Processing year 2007 for ticker CTSO.
# 2026-01-19 15:45:28,777, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CTSO/CTSO_2007
# 2026-01-19 15:45:28,784, 2113979629.py, 8, INFO, Processing year 2008 for ticker CTSO.
# 2026-01-19 15:45:28,787, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CTSO/CTSO_2008
# 2026-01-19 15:45:28,797, 2113979629.py, 8, INFO, Processing year 2009 for ticker CTSO.
# 2026-01-19 15:45:28,800, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CTSO/CTSO_2009
# 2026-01-19 15:45:28,818, 2113979629.py, 8, INFO, Processing year 2010 for ticker CTSO.
# 2026-01-19 15:45:28,823, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CTSO/CTSO_2010
# 2026-01-19 15:45:28,833, 2113979629.py, 8, INFO, Processing year 2011 for ticker CTSO.
# 2026-01-19 15:45:28,835, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CTSO/CTSO_2011
# 2026-01-19 15:45:28,842, 2113979629.py, 8, INFO, Processing year 2012 for ticker CTSO.
# 2026-01-19 15:45:28,845, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CTSO/CTSO_2012
# 2026-01-19 15:45:28,852, 2113979629.py, 8, INFO, Processing year 2013 for ticker CTSO.
# 2026-01-19 15:45:28,854, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CTSO/CTSO_2013
# 2026-01-19 15:45:28,861, 2113979629.py, 8, INFO, Processing year 2014 for ticker CTSO.
# 2026-01-19 15:45:28,863, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CTSO/CTSO_2014
# 2026-01-19 15:45:28,870, 2113979629.py, 8, INFO, Processing year 2015 for ticker CTSO.
# 2026-01-19 15:45:28,871, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CTSO/CTSO_2015
# 2026-01-19 15:45:28,879, 2113979629.py, 8, INFO, Processing year 2016 for ticker CTSO.
# 2026-01-19 15:45:28,881, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CTSO/CTSO_2016
# 2026-01-19 15:45:28,888, 2113979629.py, 8, INFO, Processing year 2017 for ticker CTSO.
# 2026-01-19 15:45:28,890, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CTSO/CTSO_2017
# 2026-01-19 15:45:28,897, 2113979629.py, 8, INFO, Processing year 2018 for ticker CTSO.
# 2026-01-19 15:45:28,900, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CTSO/CTSO_2018
# 2026-01-19 15:45:28,907, 2113979629.py, 8, INFO, Processing year 2019 for ticker CTSO.
# 2026-01-19 15:45:28,908, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CTSO/CTSO_2019
# 2026-01-19 15:45:28,915, 2113979629.py, 8, INFO, Processing year 2020 for ticker CTSO.
# 2026-01-19 15:45:28,917, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CTSO/CTSO_2020
# 2026-01-19 15:45:28,924, 2113979629.py, 4, INFO, Processing ticker: UEC
# 2026-01-19 15:45:28,937, 2113979629.py, 8, INFO, Processing year 2007 for ticker UEC.
# 2026-01-19 15:45:28,941, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/UEC/UEC_2007
# 2026-01-19 15:45:28,954, 2113979629.py, 8, INFO, Processing year 2008 for ticker UEC.
# 2026-01-19 15:45:28,957, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/UEC/UEC_2008
# 2026-01-19 15:45:28,968, 2113979629.py, 8, INFO, Processing year 2009 for ticker UEC.
# 2026-01-19 15:45:28,970, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/UEC/UEC_2009
# 2026-01-19 15:45:28,977, 2113979629.py, 8, INFO, Processing year 2010 for ticker UEC.
# 2026-01-19 15:45:28,979, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/UEC/UEC_2010
# 2026-01-19 15:45:28,986, 2113979629.py, 8, INFO, Processing year 2011 for ticker UEC.
# 2026-01-19 15:45:28,988, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/UEC/UEC_2011
# 2026-01-19 15:45:28,995, 2113979629.py, 8, INFO, Processing year 2012 for ticker UEC.
# 2026-01-19 15:45:28,996, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/UEC/UEC_2012
# 2026-01-19 15:45:29,003, 2113979629.py, 8, INFO, Processing year 2013 for ticker UEC.
# 2026-01-19 15:45:29,005, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/UEC/UEC_2013
# 2026-01-19 15:45:29,011, 2113979629.py, 8, INFO, Processing year 2014 for ticker UEC.
# 2026-01-19 15:45:29,013, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/UEC/UEC_2014
# 2026-01-19 15:45:29,020, 2113979629.py, 8, INFO, Processing year 2015 for ticker UEC.
# 2026-01-19 15:45:29,022, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/UEC/UEC_2015
# 2026-01-19 15:45:29,034, 2113979629.py, 8, INFO, Processing year 2016 for ticker UEC.
# 2026-01-19 15:45:29,036, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/UEC/UEC_2016
# 2026-01-19 15:45:29,043, 2113979629.py, 8, INFO, Processing year 2017 for ticker UEC.
# 2026-01-19 15:45:29,044, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/UEC/UEC_2017
# 2026-01-19 15:45:29,051, 2113979629.py, 8, INFO, Processing year 2018 for ticker UEC.
# 2026-01-19 15:45:29,053, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/UEC/UEC_2018
# 2026-01-19 15:45:29,059, 2113979629.py, 8, INFO, Processing year 2019 for ticker UEC.
# 2026-01-19 15:45:29,061, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/UEC/UEC_2019
# 2026-01-19 15:45:29,067, 2113979629.py, 8, INFO, Processing year 2020 for ticker UEC.
# 2026-01-19 15:45:29,069, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/UEC/UEC_2020

# %% [markdown]
# Why would we want to store data this way?
#
# + Data files are easier to maintain. We do not update old data, only recent data or the most recent "delta".
# + Parquet files, as long as they maintain a consistent schema, can all be read jointly.

# %% [markdown]
# # Load, Transform, and Save
#
# In this section, we will load the Parquet files we generated, transform the data, and save the resulting dataset.

# %% [markdown]
# ## Load
#
# + Parquet files can be read individually or as a collection.
# + `dd.read_parquet()` can take a list (collection) of files as input.
# + Use `glob` to obtain the collection of files.

# %%
from glob import glob

parquet_files = glob(os.path.join(PRICE_DATA, "**/*.parquet"), recursive = True)
_logs.info(f'Found {len(parquet_files)} parquet files for reading back into Dask.')

dd_px = dd.read_parquet(parquet_files).set_index("ticker")
# Out:
# 2026-01-19 15:46:23,182, 174194153.py, 4, INFO, Found 2010 parquet files for reading back into Dask.

# %% [markdown]
# ## Transform
#
# + This transformation step will create a *Features* data set. In our case, features will be stock returns (we obtained prices).
# + Dask dataframes work similarly to Pandas dataframes: in particular, we can perform groupby and apply operations.
# + Notice the use of [an anonymous (lambda) function](https://realpython.com/python-lambda/) in the apply statement.
#
# In the code below, the following operation occurs:
#
# + Start with a Dask dataframe, `dd_px`.
# + Group the rows of this dataframe by the variable `ticker`, i.e., each group will contain the observations that pertain only to one ticker at a time. The `group_key` parameter controls whether an index entry is added with the value of the grouping variable (`ticker` in this case); if we made `group_keys=True`, we would have a duplicate `ticker` column.
# + For each group defined by a `ticker`, `apply()` the following calculation:
#
#     - Sort the values by `Date` in ascending order.
#     - Assign a new variable called `Close_lag_1` by shifting the position of the closing price (`Close`) by one position.
#     - Define the schema of the resulting dataframe. If we omit this specification, we would get a warning; however, the simplicity of the calculation ensures that Dask can determine the resulting schema.

# %%
dd_px
# Out:
# Dask DataFrame Structure:
#                           Date     Open     High      Low    Close Adj Close   Volume  source   Year
# npartitions=60
# A               datetime64[ns]  float64  float64  float64  float64   float64  float64  string  int32
# ACB                        ...      ...      ...      ...      ...       ...      ...     ...    ...
# ...                        ...      ...      ...      ...      ...       ...      ...     ...    ...
# ZEUS                       ...      ...      ...      ...      ...       ...      ...     ...    ...
# ZEUS                       ...      ...      ...      ...      ...       ...      ...     ...    ...
# Dask Name: setindex, 2 expressions
# Expr=SetIndex(frame=ReadParquetFSSpec(eb41660), _other='ticker', options={})

# %%
dd_shift = (
    dd_px
        .groupby('ticker', group_keys=False)
        .apply(
            lambda x: x.sort_values('Date', ascending = True)
                       .assign(Close_lag_1 = x['Close'].shift(1)), 
            meta = pd.DataFrame(data ={'Date': 'datetime64[ns]',
                    'Open': 'f8',
                    'High': 'f8',
                    'Low': 'f8',
                    'Close': 'f8',
                    'Adj Close': 'f8',
                    'Volume': 'i8',
                    'source': 'object',
                    'Year': 'int32',
                    'Close_lag_1': 'f8'},
                    index = pd.Index([], dtype=pd.StringDtype(), name='ticker'))
    ))

# %% [markdown]
# Finally, using the dataframe that we created above, we can now `assign` the `Returns` variable to the entire dataset.

# %%
dd_rets = dd_shift.assign(
    Returns = lambda x: x['Close']/x['Close_lag_1'] - 1
)

# %% [markdown]
# Question: How do we know that we are not (erroneously) combining the last price of a ticker with the first price of the next ticker?

# %% [markdown]
# ## Lazy Exection
#
# What does `dd_rets` contain?

# %%
dd_rets
# Out:
# Dask DataFrame Structure:
#                   Date    Open    High     Low   Close Adj Close  Volume  source    Year Close_lag_1 Returns
# npartitions=60
# A               object  object  object  object  object    object  object  object  object      object  object
# ACB                ...     ...     ...     ...     ...       ...     ...     ...     ...         ...     ...
# ...                ...     ...     ...     ...     ...       ...     ...     ...     ...         ...     ...
# ZEUS               ...     ...     ...     ...     ...       ...     ...     ...     ...         ...     ...
# ZEUS               ...     ...     ...     ...     ...       ...     ...     ...     ...         ...     ...
# Dask Name: assign, 9 expressions
# Expr=Assign(frame=Assign(frame=GroupByApply(frame=SetIndex(frame=ReadParquetFSSpec(eb41660), _other='ticker', options={}), observed=False, group_keys=False, func=<function <lambda> at 0x135c111c0>, args=(), kwargs={})))

# %% [markdown]
# + Dask is a lazy execution framework: commands will not execute until the computation is required.
# + To trigger an execution in dask use `.compute()` or execute a command that requires the actual values (for example, write to Parquet or SQL).

# %%
dd_rets.compute()
# Out:
#              Date       Open       High        Low      Close  Adj Close  \
# ticker
# A      1999-11-18  32.546494  35.765381  28.612303  31.473534  27.068665
# A      1999-11-19  30.713520  30.758226  28.478184  28.880543  24.838577
# A      1999-11-22  29.551144  31.473534  28.657009  31.473534  27.068665
# A      1999-11-23  30.400572  31.205294  28.612303  28.612303  24.607880
# A      1999-11-24  28.701717  29.998211  28.612303  29.372318  25.261524
# ...           ...        ...        ...        ...        ...        ...
# ZEUS   2020-03-26   9.610000   9.940000   9.260000   9.590000   9.590000
# ZEUS   2020-03-27   9.330000   9.330000   8.700000   8.700000   8.700000
# ZEUS   2020-03-30   8.810000   9.760000   8.700000   9.680000   9.680000
# ZEUS   2020-03-31   9.640000  10.470000   9.590000  10.350000  10.350000
# ZEUS   2020-04-01  10.140000  10.340000   9.310000   9.470000   9.470000
#
#             Volume    source  Year  Close_lag_1   Returns
# ticker
# A       62546300.0     A.csv  1999          NaN       NaN
# A       15234100.0     A.csv  1999    31.473534 -0.082386
# A        6577800.0     A.csv  1999    28.880543  0.089783
# A        5975600.0     A.csv  1999    31.473534 -0.090909
# A        4843200.0     A.csv  1999    28.612303  0.026563
# ...            ...       ...   ...          ...       ...
# ZEUS       60500.0  ZEUS.csv  2020     9.670000 -0.008273
# ZEUS       52900.0  ZEUS.csv  2020     9.590000 -0.092805
# ZEUS       73700.0  ZEUS.csv  2020     8.700000  0.112644
# ZEUS       68900.0  ZEUS.csv  2020     9.680000  0.069215
# ZEUS       34000.0  ZEUS.csv  2020    10.350000 -0.085024
#
# [230273 rows x 11 columns]

# %% [markdown]
# ## Save
#
# With our transformed data, we can now save the new feature to a Parquet file. We will need to answer the following questions depending on our context, setup, and available resources:
#
# + Should we keep the same namespace?
# + Should we save all columns?

# %%
dd_rets
# Out:
# Dask DataFrame Structure:
#                   Date    Open    High     Low   Close Adj Close  Volume  source    Year Close_lag_1 Returns
# npartitions=60
# A               object  object  object  object  object    object  object  object  object      object  object
# ACB                ...     ...     ...     ...     ...       ...     ...     ...     ...         ...     ...
# ...                ...     ...     ...     ...     ...       ...     ...     ...     ...         ...     ...
# ZEUS               ...     ...     ...     ...     ...       ...     ...     ...     ...         ...     ...
# ZEUS               ...     ...     ...     ...     ...       ...     ...     ...     ...         ...     ...
# Dask Name: assign, 9 expressions
# Expr=Assign(frame=Assign(frame=GroupByApply(frame=SetIndex(frame=ReadParquetFSSpec(eb41660), _other='ticker', options={}), observed=False, group_keys=False, func=<function <lambda> at 0x135c111c0>, args=(), kwargs={})))

# %%
# CLean up before save
FEATURES_DATA = os.getenv("FEATURES_DATA")
if os.path.exists(FEATURES_DATA):
    shutil.rmtree(FEATURES_DATA)
dd_rets.to_parquet(FEATURES_DATA, 
                   overwrite = True, 
                   schema={
                       'Date': 'timestamp[ns]',
                       'Open': 'float64',
                       'High': 'float64',
                       'Low': 'float64',
                       'Close': 'float64',
                       'Adj Close': 'float64',
                       'Volume': 'int64',
                       'source': 'string',
                       'Year': 'int32',
                       'Close_lag_1': 'float64',
                       'Returns': 'float64',
                       'ticker': 'large_string'
                   })

# %% [markdown]
# # Optional: from Jupyter to Command Line
#
# + We have drafted our code in a Jupyter Notebook.
# + Finalized code should be written in Python modules.
#
# ## Object Oriented vs Functional Programming
#
# + We can use classes to keep parameters and functions together.
# + We *could* use Object Oriented Programming, but parallelization of data manipulation and modelling tasks benefit from *Functional Programming*.
# + An Idea:
#
#     - [Data Oriented Programming](https://blog.klipse.tech/dop/2022/06/22/principles-of-dop.html).
#     - Use the class to bundle together parameters and functions.
#     - Use stateless operations and treat all data objects as immutable (we do not modify them, we overwrite them).
#     - Take advantage of [`@staticmethod`](https://realpython.com/instance-class-and-static-methods-demystified/).
#
# The code is in `./05_src/stock_prices/data_manager.py`.

# %% [markdown]
# Our original design was:
#
# ![](./images/02_target_pipeline_manager.png)

# %%
from stock_prices.data_manager import DataManager
dm = DataManager()

# %% [markdown]
# Download all prices.

# %%
dm.process_sample_files()

# %% [markdown]
# Finally, add features to the data set and save to a *feature store*.

# %%
dm.featurize()
